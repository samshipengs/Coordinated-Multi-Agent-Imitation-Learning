# %%
import tensorflow as tf
from tensorflow.python.ops.rnn import _transpose_batch_time
from model import sampling_rnn
import numpy as np
import copy

from helpers import get_sequences, iterate_minibatches, get_minibatches

import matplotlib.pyplot as plt

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# C:\Users\sshi\AppData\Local\Continuum\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# #### First create a simple train and test set

# %%
# create a sine wave
n_samples = int(1e3)
min_x = 0
max_x = 100
x = np.linspace(min_x, max_x, n_samples)
sinx = np.sin(x)
# add a Gaussian noise to it
noise_m = 1
noise_sd = 0.5
noise = np.random.normal(noise_m, noise_sd, n_samples)
smooth = sinx+noise_m
y = sinx + noise

# %%
# plot
plt.figure(figsize=(20,5))
plt.plot(x, y, x, sinx+noise_m, 'r')
plt.grid(True)

# %%
# split it to train and test
slice_ind = int(n_samples*0.7)
# clear up namings for modeling
plot_train_x, train_original_x, plot_test_x, test_x, smooth_train_x, smooth_test_x = [x[:slice_ind], y[:slice_ind], 
                                                                             x[slice_ind:], y[slice_ind:], 
                                                                             smooth[:slice_ind], smooth[slice_ind:]]
# # chunk it to each small window
# seq_len = 5
# train_x = get_sequences(train_original_x, seq_len, 1)

# %%
# train_x.shape

# %%
# test_x.shape

# %% [markdown]
# #### So we have observed that the multiple time steps look ahead training, we want to gradually in increase the horizon
# first need to figure out how to make the model to take in dynamic sequence length if it's not by default already

# %%
# %%time
tf.reset_default_graph()

batch_size = 32
state_size = 100

# cell
lstm_cell = tf.nn.rnn_cell.BasicLSTMCell(state_size, forget_bias=1.)
# initial state
initial_state = lstm_cell.zero_state(batch_size, dtype=tf.float32)


# inputs = tf.placeholder(shape=(max_time, batch_size, input_depth),
#                         dtype=tf.float32)

# input 
h = tf.placeholder(tf.int32)
X = tf.placeholder(tf.float32, [batch_size, h, 1], name = 'train_input')
Y = tf.placeholder(tf.float32, [batch_size, h, 1], name = 'train_label')

output, last_states = sampling_rnn(cell=lstm_cell, 
                                   initial_state=initial_state, 
                                   input_=X,
                                   batch_size=batch_size)
# output as the prediction
# pred = tf.reshape(output, (batch_size, seq_len, 1))
pred = tf.reshape(output, (batch_size, 2, 1))
# pred = tf.reshape(output, (batch_size, h, 1))
# pred = _transpose_batch_time(output)

# loss
# shift to create next time step
# label = tf.manip.roll(Y, 1, axis=0)
print('label shape:{0:} | output prediction shape: {1:}'.format(Y.shape, pred.shape))
# loss
loss = tf.losses.mean_squared_error(Y, pred)
# optimzier
opt = tf.train.AdamOptimizer().minimize(loss)

# session
sess = tf.Session()
# Initializing the variables
sess.run(tf.global_variables_initializer())

# iterate
printn = 1e2
horizon = 5
for k in range(1, horizon+1):
    print('Horizon {} ======'.format(k))
    # chunk it to each small window
    seq_len = k + 1
    train_x = copy.deepcopy(get_sequences(train_original_x, seq_len, 1))
    for i in range(1000):
        epoch_loss =0.
        for batch in iterate_minibatches(train_x, np.roll(train_x, 1), batch_size, shuffle=False):
            train_xi, train_yi = batch
            p, l, _ = sess.run([output, loss, opt], feed_dict={X: train_xi, Y: train_yi, h:k})
            epoch_loss += l

        if i%printn ==0:
            print('Epoch {0:} | loss: {1:.2f}'.format(i, epoch_loss))
    break
    
    
# save model
#Create a saver object which will save all the variables
saver = tf.train.Saver()
#save the graph
saver.save(sess, save_path='./test_model')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\sshi\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in make_shape(v, arg_name)
#     140   try:
# --> 141     shape = tensor_shape.as_shape(v)
#     142   except TypeError as e:
#
# C:\Users\sshi\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_shape.py in as_shape(shape)
#     851   else:
# --> 852     return TensorShape(shape)
#     853
#
# C:\Users\sshi\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_shape.py in __init__(self, dims)
#     457         # Got a list of dimensions
# --> 458         self._dims = [as_dimension(d) for d in dims_iter]
#     459
#
# C:\Users\sshi\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_shape.py in <listcomp>(.0)
#     457         # Got a list of dimensions
# --> 458         self._dims = [as_dimension(d) for d in dims_iter]
#     459
#
# C:\Users\sshi\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_shape.py in as_dimension(value)
#     398   else:
# --> 399     return Dimension(value)
#     400
#
# C:\Users\sshi\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_shape.py in __init__(self, value)
#      33     else:
# ---> 34       self._value = int(value)
#      35       if (not isinstance(value, compat.bytes_or_text_types) and
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'Tensor'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-13056c91c6c8> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', "tf.reset_default_graph()\n\nbatch_size = 32\nstate_size = 100\n\n# cell\nlstm_cell = tf.nn.rnn_cell.BasicLSTMCell(state_size, forget_bias=1.)\n# initial state\ninitial_state = lstm_cell.zero_state(batch_size, dtype=tf.float32)\n\n\n# inputs = tf.placeholder(shape=(max_time, batch_size, input_depth),\n#                         dtype=tf.float32)\n\n# input \nh = tf.placeholder(tf.int32)\nX = tf.placeholder(tf.float32, [batch_size, h, 1], name = 'train_input')\nY = tf.placeholder(tf.float32, [batch_size, h, 1], name = 'train_label')\n\noutput, last_states = sampling_rnn(cell=lstm_cell, \n                                   initial_state=initial_state, \n                                   input_=X,\n                                   batch_size=batch_size)\n# output as the prediction\n# pred = tf.reshape(output, (batch_size, seq_len, 1))\npred = tf.reshape(output, (batch_size, 2, 1))\n# pred = tf.reshape(output, (batch_size, h, 1))\n# pred = _transpose_batch_time(output)\n\n# loss\n# shift to create next time step\n# label = tf.manip.roll(Y, 1, axis=0)\nprint('label shape:{0:} | output prediction shape: {1:}'.format(Y.shape, pred.shape))\n# loss\nloss = tf.losses.mean_squared_error(Y, pred)\n# optimzier\nopt = tf.train.AdamOptimizer().minimize(loss)\n\n# session\nsess = tf.Session()\n# Initializing the variables\nsess.run(tf.global_variables_initializer())\n\n# iterate\nprintn = 1e2\nhorizon = 5\nfor k in range(1, horizon+1):\n    print('Horizon {} ======'.format(k))\n    # chunk it to each small window\n    seq_len = k + 1\n    train_x = copy.deepcopy(get_sequences(train_original_x, seq_len, 1))\n    for i in range(1000):\n        epoch_loss =0.\n        for batch in iterate_minibatches(train_x, np.roll(train_x, 1), batch_size, shuffle=False):\n            train_xi, train_yi = batch\n            p, l, _ = sess.run([output, loss, opt], feed_dict={X: train_xi, Y: train_yi, h:k})\n            epoch_loss += l\n\n        if i%printn ==0:\n            print('Epoch {0:} | loss: {1:.2f}'.format(i, epoch_loss))\n    break\n    \n    \n# save model\n#Create a saver object which will save all the variables\nsaver = tf.train.Saver()\n#save the graph\nsaver.save(sess, save_path='./test_model')")
#
# C:\Users\sshi\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# C:\Users\sshi\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# C:\Users\sshi\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in time(self, line, cell, local_ns)
#    1183         else:
#    1184             st = clock2()
# -> 1185             exec(code, glob, local_ns)
#    1186             end = clock2()
#    1187             out = None
#
# <timed exec> in <module>()
#
# C:\Users\sshi\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py in placeholder(dtype, shape, name)
#    1744                        "eager execution.")
#    1745
# -> 1746   return gen_array_ops._placeholder(dtype=dtype, shape=shape, name=name)
#    1747
#    1748
#
# C:\Users\sshi\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in _placeholder(dtype, shape, name)
#    4020   if shape is None:
#    4021     shape = None
# -> 4022   shape = _execute.make_shape(shape, "shape")
#    4023   _ctx = _context.context()
#    4024   if _ctx.in_graph_mode():
#
# C:\Users\sshi\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in make_shape(v, arg_name)
#     141     shape = tensor_shape.as_shape(v)
#     142   except TypeError as e:
# --> 143     raise TypeError("Error converting %s to a TensorShape: %s." % (arg_name, e))
#     144   except ValueError as e:
#     145     raise ValueError("Error converting %s to a TensorShape: %s." % (arg_name,
#
# TypeError: Error converting shape to a TensorShape: int() argument must be a string, a bytes-like object or a number, not 'Tensor'.

# %%
# plt.figure(figsize=(20,8))
# if seq_len%2 == 0:
#     pl = -train_x.shape[0]
# else:
#     pl = 2
# plt.plot(train_x[:-pl], p.reshape(-1), train_x[:-pl], np.roll(train_y, 1).reshape(-1), train_x[:-pl], smooth_y_train.reshape(-1)[:-pl])
# plt.legend(['prediction', 'true label', 'smoothed'])

# %% [markdown]
# #### Test model

# %%
# make test set
test_x = get_sequences(test_x, seq_len, 1)
# randomly choose some test segment
# test_ind = np.random.randint(0, test_x.shape[0]-batch_size-1)
test_ind = 0
assert test_ind < test_x.shape[0]-batch_size-1, print('index is out of test set range with length ', len(test_x), test_x.shape[0]-batch_size-1)
ctest_x = test_x[test_ind:test_ind+batch_size, :, :]

# %%
# make plot test set
plot_test_x = get_sequences(plot_test_x, seq_len, 1)
plot_ctest_x = plot_test_x[test_ind:test_ind+batch_size, :, :]
plot_ctest_x = plot_ctest_x.reshape(-1)

# %%
# test_x, test_y = get_minibatches(test_x, np.roll(test_x, 1), 32)

# %%
test_pred = sess.run([output], feed_dict={X: ctest_x})[0]
test_pred = test_pred.reshape(-1)

# %%
plt.figure(figsize=(20,8))
plt.plot(plot_ctest_x, test_pred, plot_ctest_x, np.roll(ctest_x.reshape(-1), 1))
plt.legend(['prediction', 'true label', 'smoothed'])
plt.grid(True)
